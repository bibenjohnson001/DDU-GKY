# %% [markdown]
# ## One hot encoding and Feature Scaling

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=sns.load_dataset('titanic')

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.shape
# Out:
# (891, 15)

# %%
data.dropna(inplace=True)

# %%
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 10   child       False    G  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 871  woman       False    D  Southampton   yes  False
# 872    man        True    B  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [181 rows x 15 columns]

# %% [markdown]
# ## One hot Encoding

# %%
data['SEX']=pd.get_dummies(data=data.sex,drop_first=True)

# %%
data.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 6         0       1    male  54.0      0      0  51.8625        S  First
#
#      who  adult_male deck  embark_town alive  alone  SEX
# 1  woman       False    C    Cherbourg   yes  False    0
# 3  woman       False    C  Southampton   yes  False    0
# 6    man        True    E  Southampton    no   True    1

# %% [markdown]
# ### Converting the Entire Dataframe

# %%
data_No_Dummies = pd.get_dummies(data=data)

# %%
data_No_Dummies
# Out:
#      survived  pclass   age  sibsp  parch     fare  adult_male  alone  SEX  \
# 1           1       1  38.0      1      0  71.2833       False  False    0
# 3           1       1  35.0      1      0  53.1000       False  False    0
# 6           0       1  54.0      0      0  51.8625        True   True    1
# 10          1       3   4.0      1      1  16.7000       False  False    0
# 11          1       1  58.0      0      0  26.5500       False   True    0
# ..        ...     ...   ...    ...    ...      ...         ...    ...  ...
# 871         1       1  47.0      1      1  52.5542       False  False    0
# 872         0       1  33.0      0      0   5.0000        True   True    1
# 879         1       1  56.0      0      1  83.1583       False  False    0
# 887         1       1  19.0      0      0  30.0000       False   True    0
# 889         1       1  26.0      0      0  30.0000        True   True    1
#
#      sex_female  ...  deck_C  deck_D  deck_E  deck_F  deck_G  \
# 1             1  ...       1       0       0       0       0
# 3             1  ...       1       0       0       0       0
# 6             0  ...       0       0       1       0       0
# 10            1  ...       0       0       0       0       1
# 11            1  ...       1       0       0       0       0
# ..          ...  ...     ...     ...     ...     ...     ...
# 871           1  ...       0       1       0       0       0
# 872           0  ...       0       0       0       0       0
# 879           1  ...       1       0       0       0       0
# 887           1  ...       0       0       0       0       0
# 889           0  ...       1       0       0       0       0
#
#      embark_town_Cherbourg  embark_town_Queenstown  embark_town_Southampton  \
# 1                        1                       0                        0
# 3                        0                       0                        1
# 6                        0                       0                        1
# 10                       0                       0                        1
# 11                       0                       0                        1
# ..                     ...                     ...                      ...
# 871                      0                       0                        1
# 872                      0                       0                        1
# 879                      1                       0                        0
# 887                      0                       0                        1
# 889                      1                       0                        0
#
#      alive_no  alive_yes
# 1           0          1
# 3           0          1
# 6           1          0
# 10          0          1
# 11          0          1
# ..        ...        ...
# 871         0          1
# 872         1          0
# 879         0          1
# 887         0          1
# 889         0          1
#
# [181 rows x 32 columns]

# %%
data_No_Dummies.shape
# Out:
# (181, 32)

# %%
data_With_Dummies = pd.get_dummies(data=data,drop_first=True)

# %%
data_With_Dummies.head()
# Out:
#     survived  pclass   age  sibsp  parch     fare  adult_male  alone  SEX  \
# 1          1       1  38.0      1      0  71.2833       False  False    0
# 3          1       1  35.0      1      0  53.1000       False  False    0
# 6          0       1  54.0      0      0  51.8625        True   True    1
# 10         1       3   4.0      1      1  16.7000       False  False    0
# 11         1       1  58.0      0      0  26.5500       False   True    0
#
#     sex_male  ...  who_woman  deck_B  deck_C  deck_D  deck_E  deck_F  deck_G  \
# 1          0  ...          1       0       1       0       0       0       0
# 3          0  ...          1       0       1       0       0       0       0
# 6          1  ...          0       0       0       0       1       0       0
# 10         0  ...          0       0       0       0       0       0       1
# 11         0  ...          1       0       1       0       0       0       0
#
#     embark_town_Queenstown  embark_town_Southampton  alive_yes
# 1                        0                        0          1
# 3                        0                        1          1
# 6                        0                        1          0
# 10                       0                        1          1
# 11                       0                        1          1
#
# [5 rows x 25 columns]

# %%
data_With_Dummies.shape
# Out:
# (181, 25)

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler,RobustScaler,LabelEncoder

# %% [markdown]
# ### LABEL ENCODER

# %%
le=LabelEncoder()

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone  SEX
# 1    woman       False    C    Cherbourg   yes  False    0
# 3    woman       False    C  Southampton   yes  False    0
# 6      man        True    E  Southampton    no   True    1
# 10   child       False    G  Southampton   yes  False    0
# 11   woman       False    C  Southampton   yes   True    0
# ..     ...         ...  ...          ...   ...    ...  ...
# 871  woman       False    D  Southampton   yes  False    0
# 872    man        True    B  Southampton    no   True    1
# 879  woman       False    C    Cherbourg   yes  False    0
# 887  woman       False    B  Southampton   yes   True    0
# 889    man        True    C    Cherbourg   yes   True    1
#
# [181 rows x 16 columns]

# %%
data['EMBARKED'] = le.fit_transform(data.embarked)

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone  SEX  EMBARKED
# 1    woman       False    C    Cherbourg   yes  False    0         0
# 3    woman       False    C  Southampton   yes  False    0         2
# 6      man        True    E  Southampton    no   True    1         2
# 10   child       False    G  Southampton   yes  False    0         2
# 11   woman       False    C  Southampton   yes   True    0         2
# ..     ...         ...  ...          ...   ...    ...  ...       ...
# 871  woman       False    D  Southampton   yes  False    0         2
# 872    man        True    B  Southampton    no   True    1         2
# 879  woman       False    C    Cherbourg   yes  False    0         0
# 887  woman       False    B  Southampton   yes   True    0         2
# 889    man        True    C    Cherbourg   yes   True    1         0
#
# [181 rows x 17 columns]

# %%
data.embarked.unique()
# Out:
# array(['C', 'S', 'Q'], dtype=object)

# %% [markdown]
# #### DATA SCALING OR DATA NORMALISING

# %% [markdown]
# ###### MINMAX SCALER

# %%
minmax= MinMaxScaler()

# %%
data[['age']]
# Out:
#       age
# 1    38.0
# 3    35.0
# 6    54.0
# 10    4.0
# 11   58.0
# ..    ...
# 871  47.0
# 872  33.0
# 879  56.0
# 887  19.0
# 889  26.0
#
# [181 rows x 1 columns]

# %%
data[['EMBARKED']]
# Out:
#      EMBARKED
# 1           0
# 3           2
# 6           2
# 10          2
# 11          2
# ..        ...
# 871         2
# 872         2
# 879         0
# 887         2
# 889         0
#
# [181 rows x 1 columns]

# %%
data[['age']].values
# Out:
# array([[38.  ],
#        [35.  ],
#        [54.  ],
#        [ 4.  ],
#        [58.  ],
#        [34.  ],
#        [28.  ],
#        [19.  ],
#        [49.  ],
#        [65.  ],
#        [45.  ],
#        [29.  ],
#        [25.  ],
#        [23.  ],
#        [46.  ],
#        [71.  ],
#        [23.  ],
#        [21.  ],
#        [47.  ],
#        [24.  ],
#        [32.5 ],
#        [54.  ],
#        [19.  ],
#        [37.  ],
#        [24.  ],
#        [36.5 ],
#        [22.  ],
#        [61.  ],
#        [56.  ],
#        [50.  ],
#        [ 1.  ],
#        [ 3.  ],
#        [44.  ],
#        [58.  ],
#        [ 2.  ],
#        [40.  ],
#        [31.  ],
#        [32.  ],
#        [38.  ],
#        [35.  ],
#        [44.  ],
#        [37.  ],
#        [29.  ],
#        [62.  ],
#        [30.  ],
#        [52.  ],
#        [40.  ],
#        [58.  ],
#        [35.  ],
#        [37.  ],
#        [63.  ],
#        [19.  ],
#        [36.  ],
#        [ 2.  ],
#        [50.  ],
#        [ 0.92],
#        [17.  ],
#        [30.  ],
#        [24.  ],
#        [18.  ],
#        [31.  ],
#        [40.  ],
#        [36.  ],
#        [36.  ],
#        [16.  ],
#        [45.5 ],
#        [38.  ],
#        [29.  ],
#        [41.  ],
#        [ 2.  ],
#        [24.  ],
#        [24.  ],
#        [22.  ],
#        [60.  ],
#        [24.  ],
#        [25.  ],
#        [27.  ],
#        [36.  ],
#        [23.  ],
#        [24.  ],
#        [33.  ],
#        [32.  ],
#        [28.  ],
#        [50.  ],
#        [14.  ],
#        [64.  ],
#        [ 4.  ],
#        [52.  ],
#        [30.  ],
#        [49.  ],
#        [65.  ],
#        [48.  ],
#        [47.  ],
#        [23.  ],
#        [25.  ],
#        [35.  ],
#        [58.  ],
#        [55.  ],
#        [54.  ],
#        [25.  ],
#        [16.  ],
#        [18.  ],
#        [36.  ],
#        [47.  ],
#        [34.  ],
#        [30.  ],
#        [44.  ],
#        [45.  ],
#        [22.  ],
#        [36.  ],
#        [50.  ],
#        [17.  ],
#        [48.  ],
#        [39.  ],
#        [53.  ],
#        [36.  ],
#        [39.  ],
#        [39.  ],
#        [36.  ],
#        [18.  ],
#        [60.  ],
#        [52.  ],
#        [49.  ],
#        [40.  ],
#        [ 4.  ],
#        [42.  ],
#        [61.  ],
#        [21.  ],
#        [80.  ],
#        [32.  ],
#        [48.  ],
#        [56.  ],
#        [58.  ],
#        [47.  ],
#        [31.  ],
#        [36.  ],
#        [27.  ],
#        [15.  ],
#        [31.  ],
#        [49.  ],
#        [42.  ],
#        [18.  ],
#        [35.  ],
#        [42.  ],
#        [24.  ],
#        [48.  ],
#        [19.  ],
#        [38.  ],
#        [27.  ],
#        [27.  ],
#        [29.  ],
#        [35.  ],
#        [36.  ],
#        [21.  ],
#        [70.  ],
#        [19.  ],
#        [ 6.  ],
#        [33.  ],
#        [36.  ],
#        [51.  ],
#        [57.  ],
#        [43.  ],
#        [17.  ],
#        [29.  ],
#        [46.  ],
#        [49.  ],
#        [11.  ],
#        [39.  ],
#        [33.  ],
#        [52.  ],
#        [27.  ],
#        [39.  ],
#        [16.  ],
#        [51.  ],
#        [48.  ],
#        [31.  ],
#        [47.  ],
#        [33.  ],
#        [56.  ],
#        [19.  ],
#        [26.  ]])

# %%
age=data[['age']].values

# %%
age
# Out:
# array([[38.  ],
#        [35.  ],
#        [54.  ],
#        [ 4.  ],
#        [58.  ],
#        [34.  ],
#        [28.  ],
#        [19.  ],
#        [49.  ],
#        [65.  ],
#        [45.  ],
#        [29.  ],
#        [25.  ],
#        [23.  ],
#        [46.  ],
#        [71.  ],
#        [23.  ],
#        [21.  ],
#        [47.  ],
#        [24.  ],
#        [32.5 ],
#        [54.  ],
#        [19.  ],
#        [37.  ],
#        [24.  ],
#        [36.5 ],
#        [22.  ],
#        [61.  ],
#        [56.  ],
#        [50.  ],
#        [ 1.  ],
#        [ 3.  ],
#        [44.  ],
#        [58.  ],
#        [ 2.  ],
#        [40.  ],
#        [31.  ],
#        [32.  ],
#        [38.  ],
#        [35.  ],
#        [44.  ],
#        [37.  ],
#        [29.  ],
#        [62.  ],
#        [30.  ],
#        [52.  ],
#        [40.  ],
#        [58.  ],
#        [35.  ],
#        [37.  ],
#        [63.  ],
#        [19.  ],
#        [36.  ],
#        [ 2.  ],
#        [50.  ],
#        [ 0.92],
#        [17.  ],
#        [30.  ],
#        [24.  ],
#        [18.  ],
#        [31.  ],
#        [40.  ],
#        [36.  ],
#        [36.  ],
#        [16.  ],
#        [45.5 ],
#        [38.  ],
#        [29.  ],
#        [41.  ],
#        [ 2.  ],
#        [24.  ],
#        [24.  ],
#        [22.  ],
#        [60.  ],
#        [24.  ],
#        [25.  ],
#        [27.  ],
#        [36.  ],
#        [23.  ],
#        [24.  ],
#        [33.  ],
#        [32.  ],
#        [28.  ],
#        [50.  ],
#        [14.  ],
#        [64.  ],
#        [ 4.  ],
#        [52.  ],
#        [30.  ],
#        [49.  ],
#        [65.  ],
#        [48.  ],
#        [47.  ],
#        [23.  ],
#        [25.  ],
#        [35.  ],
#        [58.  ],
#        [55.  ],
#        [54.  ],
#        [25.  ],
#        [16.  ],
#        [18.  ],
#        [36.  ],
#        [47.  ],
#        [34.  ],
#        [30.  ],
#        [44.  ],
#        [45.  ],
#        [22.  ],
#        [36.  ],
#        [50.  ],
#        [17.  ],
#        [48.  ],
#        [39.  ],
#        [53.  ],
#        [36.  ],
#        [39.  ],
#        [39.  ],
#        [36.  ],
#        [18.  ],
#        [60.  ],
#        [52.  ],
#        [49.  ],
#        [40.  ],
#        [ 4.  ],
#        [42.  ],
#        [61.  ],
#        [21.  ],
#        [80.  ],
#        [32.  ],
#        [48.  ],
#        [56.  ],
#        [58.  ],
#        [47.  ],
#        [31.  ],
#        [36.  ],
#        [27.  ],
#        [15.  ],
#        [31.  ],
#        [49.  ],
#        [42.  ],
#        [18.  ],
#        [35.  ],
#        [42.  ],
#        [24.  ],
#        [48.  ],
#        [19.  ],
#        [38.  ],
#        [27.  ],
#        [27.  ],
#        [29.  ],
#        [35.  ],
#        [36.  ],
#        [21.  ],
#        [70.  ],
#        [19.  ],
#        [ 6.  ],
#        [33.  ],
#        [36.  ],
#        [51.  ],
#        [57.  ],
#        [43.  ],
#        [17.  ],
#        [29.  ],
#        [46.  ],
#        [49.  ],
#        [11.  ],
#        [39.  ],
#        [33.  ],
#        [52.  ],
#        [27.  ],
#        [39.  ],
#        [16.  ],
#        [51.  ],
#        [48.  ],
#        [31.  ],
#        [47.  ],
#        [33.  ],
#        [56.  ],
#        [19.  ],
#        [26.  ]])

# %%
data[['age']].values
# Out:
# array([[38.  ],
#        [35.  ],
#        [54.  ],
#        [ 4.  ],
#        [58.  ],
#        [34.  ],
#        [28.  ],
#        [19.  ],
#        [49.  ],
#        [65.  ],
#        [45.  ],
#        [29.  ],
#        [25.  ],
#        [23.  ],
#        [46.  ],
#        [71.  ],
#        [23.  ],
#        [21.  ],
#        [47.  ],
#        [24.  ],
#        [32.5 ],
#        [54.  ],
#        [19.  ],
#        [37.  ],
#        [24.  ],
#        [36.5 ],
#        [22.  ],
#        [61.  ],
#        [56.  ],
#        [50.  ],
#        [ 1.  ],
#        [ 3.  ],
#        [44.  ],
#        [58.  ],
#        [ 2.  ],
#        [40.  ],
#        [31.  ],
#        [32.  ],
#        [38.  ],
#        [35.  ],
#        [44.  ],
#        [37.  ],
#        [29.  ],
#        [62.  ],
#        [30.  ],
#        [52.  ],
#        [40.  ],
#        [58.  ],
#        [35.  ],
#        [37.  ],
#        [63.  ],
#        [19.  ],
#        [36.  ],
#        [ 2.  ],
#        [50.  ],
#        [ 0.92],
#        [17.  ],
#        [30.  ],
#        [24.  ],
#        [18.  ],
#        [31.  ],
#        [40.  ],
#        [36.  ],
#        [36.  ],
#        [16.  ],
#        [45.5 ],
#        [38.  ],
#        [29.  ],
#        [41.  ],
#        [ 2.  ],
#        [24.  ],
#        [24.  ],
#        [22.  ],
#        [60.  ],
#        [24.  ],
#        [25.  ],
#        [27.  ],
#        [36.  ],
#        [23.  ],
#        [24.  ],
#        [33.  ],
#        [32.  ],
#        [28.  ],
#        [50.  ],
#        [14.  ],
#        [64.  ],
#        [ 4.  ],
#        [52.  ],
#        [30.  ],
#        [49.  ],
#        [65.  ],
#        [48.  ],
#        [47.  ],
#        [23.  ],
#        [25.  ],
#        [35.  ],
#        [58.  ],
#        [55.  ],
#        [54.  ],
#        [25.  ],
#        [16.  ],
#        [18.  ],
#        [36.  ],
#        [47.  ],
#        [34.  ],
#        [30.  ],
#        [44.  ],
#        [45.  ],
#        [22.  ],
#        [36.  ],
#        [50.  ],
#        [17.  ],
#        [48.  ],
#        [39.  ],
#        [53.  ],
#        [36.  ],
#        [39.  ],
#        [39.  ],
#        [36.  ],
#        [18.  ],
#        [60.  ],
#        [52.  ],
#        [49.  ],
#        [40.  ],
#        [ 4.  ],
#        [42.  ],
#        [61.  ],
#        [21.  ],
#        [80.  ],
#        [32.  ],
#        [48.  ],
#        [56.  ],
#        [58.  ],
#        [47.  ],
#        [31.  ],
#        [36.  ],
#        [27.  ],
#        [15.  ],
#        [31.  ],
#        [49.  ],
#        [42.  ],
#        [18.  ],
#        [35.  ],
#        [42.  ],
#        [24.  ],
#        [48.  ],
#        [19.  ],
#        [38.  ],
#        [27.  ],
#        [27.  ],
#        [29.  ],
#        [35.  ],
#        [36.  ],
#        [21.  ],
#        [70.  ],
#        [19.  ],
#        [ 6.  ],
#        [33.  ],
#        [36.  ],
#        [51.  ],
#        [57.  ],
#        [43.  ],
#        [17.  ],
#        [29.  ],
#        [46.  ],
#        [49.  ],
#        [11.  ],
#        [39.  ],
#        [33.  ],
#        [52.  ],
#        [27.  ],
#        [39.  ],
#        [16.  ],
#        [51.  ],
#        [48.  ],
#        [31.  ],
#        [47.  ],
#        [33.  ],
#        [56.  ],
#        [19.  ],
#        [26.  ]])

# %%
data['AGE']=minmax.fit_transform(age)

# %%
data.head(5)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 6          0       1    male  54.0      0      0  51.8625        S  First
# 10         1       3  female   4.0      1      1  16.7000        S  Third
# 11         1       1  female  58.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone  SEX  EMBARKED       AGE
# 1   woman       False    C    Cherbourg   yes  False    0         0  0.468892
# 3   woman       False    C  Southampton   yes  False    0         2  0.430956
# 6     man        True    E  Southampton    no   True    1         2  0.671219
# 10  child       False    G  Southampton   yes  False    0         2  0.038948
# 11  woman       False    C  Southampton   yes   True    0         2  0.721801

# %%
data.AGE.min()
# Out:
# 0.0

# %%
data.AGE.max()
# Out:
# 1.0

# %% [markdown]
# ### Standartd Scaler

# %%
sc=StandardScaler()

# %%
data['AGE_SC']=sc.fit_transform(age)

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone  SEX  EMBARKED  \
# 1    woman       False    C    Cherbourg   yes  False    0         0
# 3    woman       False    C  Southampton   yes  False    0         2
# 6      man        True    E  Southampton    no   True    1         2
# 10   child       False    G  Southampton   yes  False    0         2
# 11   woman       False    C  Southampton   yes   True    0         2
# ..     ...         ...  ...          ...   ...    ...  ...       ...
# 871  woman       False    D  Southampton   yes  False    0         2
# 872    man        True    B  Southampton    no   True    1         2
# 879  woman       False    C    Cherbourg   yes  False    0         0
# 887  woman       False    B  Southampton   yes   True    0         2
# 889    man        True    C    Cherbourg   yes   True    1         0
#
#           AGE    AGE_SC
# 1    0.468892  0.147792
# 3    0.430956 -0.043930
# 6    0.671219  1.170310
# 10   0.038948 -2.025058
# 11   0.721801  1.425939
# ..        ...       ...
# 871  0.582701  0.722958
# 872  0.405665 -0.171745
# 879  0.696510  1.298124
# 887  0.228629 -1.066448
# 889  0.317147 -0.619096
#
# [181 rows x 19 columns]

# %%
data.AGE_SC.min()
# Out:
# -2.221892714597594

# %%
data.AGE_SC.max()
# Out:
# 2.83190075622482

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone  SEX  EMBARKED  \
# 1    woman       False    C    Cherbourg   yes  False    0         0
# 3    woman       False    C  Southampton   yes  False    0         2
# 6      man        True    E  Southampton    no   True    1         2
# 10   child       False    G  Southampton   yes  False    0         2
# 11   woman       False    C  Southampton   yes   True    0         2
# ..     ...         ...  ...          ...   ...    ...  ...       ...
# 871  woman       False    D  Southampton   yes  False    0         2
# 872    man        True    B  Southampton    no   True    1         2
# 879  woman       False    C    Cherbourg   yes  False    0         0
# 887  woman       False    B  Southampton   yes   True    0         2
# 889    man        True    C    Cherbourg   yes   True    1         0
#
#           AGE    AGE_SC
# 1    0.468892  0.147792
# 3    0.430956 -0.043930
# 6    0.671219  1.170310
# 10   0.038948 -2.025058
# 11   0.721801  1.425939
# ..        ...       ...
# 871  0.582701  0.722958
# 872  0.405665 -0.171745
# 879  0.696510  1.298124
# 887  0.228629 -1.066448
# 889  0.317147 -0.619096
#
# [181 rows x 19 columns]

# %%
data3=data.iloc[57:78]

# %%
data3
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 309         1       1  female  30.0      0      0   56.9292        C   First
# 310         1       1  female  24.0      0      0   83.1583        C   First
# 311         1       1  female  18.0      2      2  262.3750        C   First
# 318         1       1  female  31.0      0      2  164.8667        S   First
# 319         1       1  female  40.0      1      1  134.5000        C   First
# 325         1       1  female  36.0      0      0  135.6333        C   First
# 327         1       2  female  36.0      0      0   13.0000        S  Second
# 329         1       1  female  16.0      0      1   57.9792        C   First
# 331         0       1    male  45.5      0      0   28.5000        S   First
# 332         0       1    male  38.0      0      1  153.4625        S   First
# 336         0       1    male  29.0      1      0   66.6000        S   First
# 337         1       1  female  41.0      0      0  134.5000        C   First
# 340         1       2    male   2.0      1      1   26.0000        S  Second
# 341         1       1  female  24.0      3      2  263.0000        S   First
# 345         1       2  female  24.0      0      0   13.0000        S  Second
# 356         1       1  female  22.0      0      1   55.0000        S   First
# 366         1       1  female  60.0      1      0   75.2500        C   First
# 369         1       1  female  24.0      0      0   69.3000        C   First
# 370         1       1    male  25.0      1      0   55.4417        C   First
# 377         0       1    male  27.0      0      2  211.5000        C   First
# 390         1       1    male  36.0      1      2  120.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone  SEX  EMBARKED  \
# 309  woman       False    E    Cherbourg   yes   True    0         0
# 310  woman       False    C    Cherbourg   yes   True    0         0
# 311  woman       False    B    Cherbourg   yes  False    0         0
# 318  woman       False    C  Southampton   yes  False    0         2
# 319  woman       False    E    Cherbourg   yes  False    0         0
# 325  woman       False    C    Cherbourg   yes   True    0         0
# 327  woman       False    D  Southampton   yes   True    0         2
# 329  woman       False    B    Cherbourg   yes  False    0         0
# 331    man        True    C  Southampton    no   True    1         2
# 332    man        True    C  Southampton    no  False    1         2
# 336    man        True    C  Southampton    no  False    1         2
# 337  woman       False    E    Cherbourg   yes   True    0         0
# 340  child       False    F  Southampton   yes  False    1         2
# 341  woman       False    C  Southampton   yes  False    0         2
# 345  woman       False    F  Southampton   yes   True    0         2
# 356  woman       False    E  Southampton   yes  False    0         2
# 366  woman       False    D    Cherbourg   yes  False    0         0
# 369  woman       False    B    Cherbourg   yes   True    0         0
# 370    man        True    E    Cherbourg   yes  False    1         0
# 377    man        True    C    Cherbourg    no  False    1         0
# 390    man        True    B  Southampton   yes  False    1         2
#
#           AGE    AGE_SC
# 309  0.367729 -0.363467
# 310  0.291856 -0.746911
# 311  0.215984 -1.130355
# 318  0.380374 -0.299560
# 319  0.494183  0.275607
# 325  0.443601  0.019977
# 327  0.443601  0.019977
# 329  0.190693 -1.258170
# 331  0.563733  0.627097
# 332  0.468892  0.147792
# 336  0.355083 -0.427374
# 337  0.506829  0.339514
# 340  0.013657 -2.152873
# 341  0.291856 -0.746911
# 345  0.291856 -0.746911
# 356  0.266566 -0.874726
# 366  0.747092  1.553754
# 369  0.291856 -0.746911
# 370  0.304502 -0.683004
# 377  0.329793 -0.555189
# 390  0.443601  0.019977

# %%
data3=data3.groupby(['embarked'])['fare'].sum()

# %%
data3
# Out:
# embarked
# C    1276.5667
# S     903.4292
# Name: fare, dtype: float64
